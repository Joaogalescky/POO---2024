// %% [markdown]
// # Exercício 01
// <p style="text-align:justify;">
// Crie um programa que armazene um vetor com as notas de dez alunos, calcule e imprima a média dessas notas e depois informe a quantidade de notas acima e abaixo da média calculada.
// </p>

// %%
import java.util.Scanner;

//public class Ex01 {
    //public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        double[] vetor = new double[10];
        double media = 0;
        int acima = 0, abaixo = 0;

        for (int i = 0; i < vetor.length; i++) {
            double n = sc.nextDouble();
            vetor[i] = n;
            media += n;
        }

        media = media / vetor.length;

        for (int j = 0; j < vetor.length; j++) {
            if (vetor[j] >= media) {
                acima++;
            } else {
                abaixo++;
            }
        }
        System.out.printf("A média geral de todas as notas é: %.2f\n", media);
        System.out.printf("A quantidade de notas a cima da média é: %d\n", acima);
        System.out.printf("A quantidade de notas abaixo da média é: %d\n", abaixo);
        sc.close();
    //}
//}
// Out:
//  5
//  8
//  9
//  7
//  4
//  6
//  5.5
//  5.7
//  8.5
//  9.5
// A média geral de todas as notas é: 6.82
// A quantidade de notas a cima da média é: 5
// A quantidade de notas abaixo da média é: 5
// null

// %% [markdown]
// # Exercício 02
// <p style="text-align:justify;">
// Construa uma classe em Java que seja capaz de efetuar a leitura de uma matriz de valores reais de tamanho 3 x 3, calculando seu determinante.
// </p>

// %%
import java.util.Scanner;

//public class Ex02 {
    //public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        double[][] matriz = new double[3][3];
        double determinante;

        for (int i = 0; i < matriz.length; i++) {
            for (int j = 0; j < matriz.length; j++) {
                System.out.println("Digite o elemento [" + (i + 1) + "][" + (j + 1) + "]: ");
                matriz[i][j] = sc.nextDouble();
            }
        }
        /* Fórmula do determinante de uma matriz 3x3:
         det(A) = a11(a22*a33 - a23*a32) - a12(a21*a33 - a23*a31) + a13(a21*a32 - a22*a31)
        */
        determinante = matriz[0][0] * (matriz[1][1] * matriz[2][2] - matriz[1][2] * matriz[2][1])
                - matriz[0][1] * (matriz[1][0] * matriz[2][2] - matriz[1][2] * matriz[2][0])
                + matriz[0][2] * (matriz[1][0] * matriz[2][1] - matriz[1][1] * matriz[2][0]);
        System.out.println("O determinante da matriz é: " + determinante);
        sc.close();
    //}
//}
// Out:
// Digite o elemento [1][1]:
//  5
// Digite o elemento [1][2]:
//  8
// Digite o elemento [1][3]:
//  4
// Digite o elemento [2][1]:
//  3
// Digite o elemento [2][2]:
//  9
// Digite o elemento [2][3]:
//  6
// Digite o elemento [3][1]:
//  7
// Digite o elemento [3][2]:
//  2
// Digite o elemento [3][3]:
//  1
// O determinante da matriz é: 69.0
// null

// %% [markdown]
// # Exercício 03
// <p style="text-align:justify;">
// Faça uma classe contendo dois arrays do tipo inteiro, um chamado par e outro chamado ímpar. Cada array deve conter 10 elementos. A seguir, faça um laço de repetição com 10 iterações e que contenha internamente a geração randômica de números entre 1 e 20. Se o valor gerado for par, armazene no array chamado par, caso contrário, no array chamado impar. Ao final, apresente o conteúdo de cada um dos arrays.
// </p>

// %%
import java.util.Random;

//public class Ex03{
    //public static void main(String[] args) {
        int[] par = new int[10];
        int[] impar = new int[10];
        Random aleatorio = new Random();

        for (int i = 0; i < 10; i++) {
            int n = aleatorio.nextInt(20) + 1;
            if (n % 2 == 0) {
                par[i] = n;
            } else {
                impar[i] = n;
            }
        }

        // Saída do vetor par
        System.out.println("Números pares:");
        for (int i = 0; i < par.length; i++) {
            if (par[i] != 0) {
                System.out.print(par[i] + " ");
            }
        }
        System.out.println();

        // Saída do vetor impar
        System.out.println("Números ímpares:");
        for (int i = 0; i < impar.length; i++) {
            if (impar[i] != 0) {
                System.out.print(impar[i] + " ");
            }
        }
    System.out.println();
//}
// Out:
// Números pares:
// 2 10 10 16
// Números ímpares:
// 5 13 17 15 11 19
// null

// %% [markdown]
// # Exercício 04
// <p style="text-align:justify;">
// Usando um array unidimensional de 10 elementos do tipo String, faça uma classe que simule a ocupação de um estacionamento de veículos. Considere que a posição do array corresponde ao número da vaga e para cada vaga é armazenada a placa do veículo que está estacionado. Sua classe deve conter um laço de repetição simulando um menu que controle a entrada e a saída dos veículos com as opções: 1-Entrada, 2-Saída e 3-Listar situação atual e 4-Encerrar o programa. Se o usuário escolher 1, solicite o número da vaga e a placa do veículo; se escolher 2, solicite o número da vaga que será liberada e armazene o valor branco na posição correspondente ao array; se escolher 3, liste a situação atual apresentando em tela todos os elementos do array; quando for 4, encerre o laço e o programa.
// </p>

// %%
import java.util.Scanner;

//public class Ex04x {
    //public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        String[] vagas = new String[10];
        boolean sair = false;
        int nVaga;

        while (!sair) {
            System.out.println("\nMenu:");
            System.out.println("1 - Entrada");
            System.out.println("2 - Saída");
            System.out.println("3 - Listar situação atual");
            System.out.println("4 - Encerrar o programa");
            System.out.print("Escolha uma opção: ");
            int opcao = sc.nextInt();

            switch (opcao) {
                case 1:
                    System.out.print("Digite o número da vaga: ");
                    nVaga = sc.nextInt();
                    sc.nextLine(); // Limpar o buffer de entrada
                    if (nVaga < vagas.length) {
                        if (vagas[nVaga] == null || vagas[nVaga].isEmpty()) {
                            System.out.print("Digite a placa do veículo: ");
                            String placa = sc.nextLine();
                            vagas[nVaga] = placa;
                            System.out.println("Veículo estacionado na vaga " + nVaga);
                        } else {
                            System.out.println("Esta vaga já está ocupada.");
                        }
                    } else {
                        System.out.println("Vaga inválida! Tente novamente.");
                    }
                    break;
                case 2:
                    System.out.print("Digite o número da vaga que será liberada: ");
                    nVaga = sc.nextInt();

                    if (nVaga < vagas.length) {
                        vagas[nVaga] = "";
                        System.out.println("Vaga " + nVaga + " liberada.");
                    } else {
                        System.out.println("Vaga inválida! Tente novamente.");
                    }
                    ;
                    break;
                case 3:
                    System.out.println("\nSituação atual do estacionamento:");

                    for (int i = 0; i < vagas.length; i++) {
                        if (vagas[i] == null || vagas[i].isEmpty()) {
                            System.out.println("Vaga " + i + ": vazia");
                        } else {
                            System.out.println("Vaga " + i + ": " + vagas[i]);
                        }
                    }
                    break;
                case 4:
                    sair = true;
                    break;
                default:
                    System.out.println("Opção inválida! Tente novamente.");
            }
        }
    //}
//}
// Out:
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  1
// Digite o número da vaga:
//  5
// Digite a placa do veículo:
//  HHUT5
// Veículo estacionado na vaga 5
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  3
// Situação atual do estacionamento:
// Vaga 0: vazia
// Vaga 1: vazia
// Vaga 2: vazia
// Vaga 3: vazia
// Vaga 4: vazia
// Vaga 5: HHUT5
// Vaga 6: vazia
// Vaga 7: vazia
// Vaga 8: vazia
// Vaga 9: vazia
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  2
// Digite o número da vaga que será liberada:
//  5
// Vaga 5 liberada.
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  3
// Situação atual do estacionamento:
// Vaga 0: vazia
// Vaga 1: vazia
// Vaga 2: vazia
// Vaga 3: vazia
// Vaga 4: vazia
// Vaga 5: vazia
// Vaga 6: vazia
// Vaga 7: vazia
// Vaga 8: vazia
// Vaga 9: vazia
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  1
// Digite o número da vaga:
//  1
// Digite a placa do veículo:
//  TYU7
// Veículo estacionado na vaga 1
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  1
// Digite o número da vaga:
//  1
// Esta vaga já está ocupada.
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  2
// Digite o número da vaga que será liberada:
//  1
// Vaga 1 liberada.
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  2
// Digite o número da vaga que será liberada:
//  1
// Vaga 1 liberada.
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  3
// Situação atual do estacionamento:
// Vaga 0: vazia
// Vaga 1: vazia
// Vaga 2: vazia
// Vaga 3: vazia
// Vaga 4: vazia
// Vaga 5: vazia
// Vaga 6: vazia
// Vaga 7: vazia
// Vaga 8: vazia
// Vaga 9: vazia
//
// Menu:
// 1 - Entrada
// 2 - Saída
// 3 - Listar situação atual
// 4 - Encerrar o programa
// Escolha uma opção:
//  4
// null

// %% [markdown]
// # Exercício 05
// <p style="text-align:justify;">
// Uma imagem é formada por pixels. Considere uma imagem com dimensão de 40 x 40 e faça uma classe que contenha um array bidimensional com essas dimensões. A seguir, para cada posição
// desse array bidimensional armazene um valor aleatório entre 0 e 255 (esses valores correspondem às tonalidades aplicadas sobre a imagem). Apresente em tela os 1600 valores gerados.
// </p>

// %%
import java.util.Random;

//public class Ex05 {
    //public static void main(String[] args) {
        int[][] imagem = new int[40][40];
        Random aleatorio = new Random();

        for (int i = 0; i < 40; i++) {
            for (int j = 0; j < 40; j++) {
                // Gerar um número aleatório entre 0 e 255
                imagem[i][j] = aleatorio.nextInt(256); 
            }
        }

        for (int i = 0; i < 40; i++) {
            for (int j = 0; j < 40; j++) {
                System.out.print(imagem[i][j] + " ");
            }
            System.out.println();
        }
    //}
//}
// Out:
// 106 78 220 112 141 226 92 236 191 216 221 238 60 98 236 226 195 183 196 110 133 168 6 186 16 215 239 91 225 144 122 214 232 80 19 225 75 157 109 33
// 235 125 179 164 190 86 154 118 100 154 181 24 68 115 115 111 122 83 161 249 135 252 59 217 66 249 31 52 43 121 243 161 237 56 41 0 82 62 247 112
// 185 227 187 157 249 143 68 168 99 101 252 189 183 169 179 22 31 128 126 105 128 39 232 55 235 145 189 191 216 3 70 110 50 77 238 221 139 106 9 90
// 100 250 8 209 228 8 131 3 255 124 59 121 166 228 168 72 19 37 17 210 192 233 31 201 248 36 61 75 238 67 176 58 46 142 67 117 219 67 59 206
